# %%
from pathlib import Path
import re

import pandas as pd
import numpy as np

from compgen2 import Gov, Matcher, const, Preprocessing

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Showcase Preprocessing

# %% [markdown]
# #### Kreiere Testset mit typischen Fehlern

# %%
data_root = Path("../data")

# %%
# Lade verlustliste
vl = pd.read_parquet(data_root / const.FILENAME_VL)

# %%
testset = pd.concat([vl[vl.location.str.contains("[A-Za-zäöüÄÖÜßẞ]+\.")].sample(n=12, random_state=10),
                    vl[vl.location.str.contains("kr\.")].sample(n=3, random_state=10),
                    vl[vl.location.str.contains("[\[{(]")].sample(n=5, random_state=10),
                    vl[vl.location.str.contains(" verm.")].sample(n=2, random_state=10),
                    vl[vl.location.str.contains(" nicht")].sample(n=3, random_state=10),
                    vl[vl.location.str.contains("[#^]")].sample(n=2, random_state=10)]).drop(['loc_parts_count', 'loc_count'], axis=1).sample(frac=1, random_state=10).reset_index(drop=True)
testset
# Out:
#                                         location
# 0                       Ostrowine, Oels, Schles.
# 1                      Wald b. Neuburg, Schwaben
# 2                   Rüstenhart, Gebweiler (Els.)
# 3                                Obkaß, vermutl.
# 4                      Gr. Grävendorf, Merseburg
# 5                                 Bühl, Ob. Els.
# 6                      Uhlbach,  O.-A. Cannstatt
# 7                                Wettin, Sallkr.
# 8                  Pietenhofen, nicht Putenkofen
# 9                 Friedrichroda, Mansf. Gebgskr.
# 10                   Hamerode, Mansf. Gebirgskr.
# 11                               Gorko, vermutl.
# 12                           Unterimbach, Mtlfr.
# 13                                    Frankfurt^
# 14               Wenig-Lessen, Grünberg i. Schl.
# 15                         S{.}abott, Hohensalza
# 16                              Burgfelden i. E.
# 17                      Scheuder, nicht Schender
# 18                          Liebenthal, Potsdam^
# 19                         N. Breisig, Ahrweiler
# 20                   Oberhausen, nicht Oberhauen
# 21          Diehlhausen [Dietenhausen], Oberlahn
# 22  Euschertsfurth, Bayern [nicht Enschertsfurt]
# 23                        Vogelbach, St. Blasien
# 24                   Freiburg (nicht Rothenfels)
# 25                              Barleben (vmtl.)
# 26                           Thalheim, Mittelfr.

# %% [markdown]
# ### *Sonderzeichen*: 1. Entfernen der Korrekturen

# %% [markdown]
# Function replace_corrections_vl() for removing historical corrections '()[]' and modern-day corrections '{}' and variants
# 1. brackets including their content
# 2. the word 'nicht' plus related content
# 3. the word 'korrigiert' and its variants plus related content
# 4. the word 'vermutlich' and its variants plus related content

# %%
testset['replace_corrs'] = Preprocessing.replace_corrections_vl(testset.location)
testset
# Out:
#                                         location  \
# 0                       Ostrowine, Oels, Schles.
# 1                      Wald b. Neuburg, Schwaben
# 2                   Rüstenhart, Gebweiler (Els.)
# 3                                Obkaß, vermutl.
# 4                      Gr. Grävendorf, Merseburg
# 5                                 Bühl, Ob. Els.
# 6                      Uhlbach,  O.-A. Cannstatt
# 7                                Wettin, Sallkr.
# 8                  Pietenhofen, nicht Putenkofen
# 9                 Friedrichroda, Mansf. Gebgskr.
# 10                   Hamerode, Mansf. Gebirgskr.
# 11                               Gorko, vermutl.
# 12                           Unterimbach, Mtlfr.
# 13                                    Frankfurt^
# 14               Wenig-Lessen, Grünberg i. Schl.
# 15                         S{.}abott, Hohensalza
# 16                              Burgfelden i. E.
# 17                      Scheuder, nicht Schender
# 18                          Liebenthal, Potsdam^
# 19                         N. Breisig, Ahrweiler
# 20                   Oberhausen, nicht Oberhauen
# 21          Diehlhausen [Dietenhausen], Oberlahn
# 22  Euschertsfurth, Bayern [nicht Enschertsfurt]
# 23                        Vogelbach, St. Blasien
# 24                   Freiburg (nicht Rothenfels)
# 25                              Barleben (vmtl.)
# 26                           Thalheim, Mittelfr.
#
#                       replace_corrs
# 0          Ostrowine, Oels, Schles.
# 1         Wald b. Neuburg, Schwaben
# 2            Rüstenhart, Gebweiler
# 3                             Obkaß
# 4         Gr. Grävendorf, Merseburg
# 5                    Bühl, Ob. Els.
# 6         Uhlbach,  O.-A. Cannstatt
# 7                   Wettin, Sallkr.
# 8                       Pietenhofen
# 9    Friedrichroda, Mansf. Gebgskr.
# 10      Hamerode, Mansf. Gebirgskr.
# 11                            Gorko
# 12              Unterimbach, Mtlfr.
# 13                       Frankfurt^
# 14  Wenig-Lessen, Grünberg i. Schl.
# 15               Sabott, Hohensalza
# 16                 Burgfelden i. E.
# 17                         Scheuder
# 18             Liebenthal, Potsdam^
# 19            N. Breisig, Ahrweiler
# 20                       Oberhausen
# 21           Diehlhausen , Oberlahn
# 22          Euschertsfurth, Bayern
# 23           Vogelbach, St. Blasien
# 24                        Freiburg
# 25                        Barleben
# 26              Thalheim, Mittelfr.

# %% [markdown]
# ### *Sonderzeichen*: 2. Entfernen weiterer Sonderzeichen

# %% [markdown]
# Function for removing special characters:
# 1. simply removed: ?^_"#*\:{}()[]!
# 2. replaced with ': ´`

# %%
testset['replace_chars'] = Preprocessing.replace_characters_vl(testset.replace_corrs)
testset
# Out:
#                                         location  \
# 0                       Ostrowine, Oels, Schles.
# 1                      Wald b. Neuburg, Schwaben
# 2                   Rüstenhart, Gebweiler (Els.)
# 3                                Obkaß, vermutl.
# 4                      Gr. Grävendorf, Merseburg
# 5                                 Bühl, Ob. Els.
# 6                      Uhlbach,  O.-A. Cannstatt
# 7                                Wettin, Sallkr.
# 8                  Pietenhofen, nicht Putenkofen
# 9                 Friedrichroda, Mansf. Gebgskr.
# 10                   Hamerode, Mansf. Gebirgskr.
# 11                               Gorko, vermutl.
# 12                           Unterimbach, Mtlfr.
# 13                                    Frankfurt^
# 14               Wenig-Lessen, Grünberg i. Schl.
# 15                         S{.}abott, Hohensalza
# 16                              Burgfelden i. E.
# 17                      Scheuder, nicht Schender
# 18                          Liebenthal, Potsdam^
# 19                         N. Breisig, Ahrweiler
# 20                   Oberhausen, nicht Oberhauen
# 21          Diehlhausen [Dietenhausen], Oberlahn
# 22  Euschertsfurth, Bayern [nicht Enschertsfurt]
# 23                        Vogelbach, St. Blasien
# 24                   Freiburg (nicht Rothenfels)
# 25                              Barleben (vmtl.)
# 26                           Thalheim, Mittelfr.
#
#                       replace_corrs                    replace_chars
# 0          Ostrowine, Oels, Schles.         Ostrowine, Oels, Schles.
# 1         Wald b. Neuburg, Schwaben        Wald b. Neuburg, Schwaben
# 2            Rüstenhart, Gebweiler            Rüstenhart, Gebweiler
# 3                             Obkaß                            Obkaß
# 4         Gr. Grävendorf, Merseburg        Gr. Grävendorf, Merseburg
# 5                    Bühl, Ob. Els.                   Bühl, Ob. Els.
# 6         Uhlbach,  O.-A. Cannstatt        Uhlbach,  O.-A. Cannstatt
# 7                   Wettin, Sallkr.                  Wettin, Sallkr.
# 8                       Pietenhofen                      Pietenhofen
# 9    Friedrichroda, Mansf. Gebgskr.   Friedrichroda, Mansf. Gebgskr.
# 10      Hamerode, Mansf. Gebirgskr.      Hamerode, Mansf. Gebirgskr.
# 11                            Gorko                            Gorko
# 12              Unterimbach, Mtlfr.              Unterimbach, Mtlfr.
# 13                       Frankfurt^                        Frankfurt
# 14  Wenig-Lessen, Grünberg i. Schl.  Wenig-Lessen, Grünberg i. Schl.
# 15               Sabott, Hohensalza               Sabott, Hohensalza
# 16                 Burgfelden i. E.                 Burgfelden i. E.
# 17                         Scheuder                         Scheuder
# 18             Liebenthal, Potsdam^              Liebenthal, Potsdam
# 19            N. Breisig, Ahrweiler            N. Breisig, Ahrweiler
# 20                       Oberhausen                       Oberhausen
# 21           Diehlhausen , Oberlahn           Diehlhausen , Oberlahn
# 22          Euschertsfurth, Bayern           Euschertsfurth, Bayern
# 23           Vogelbach, St. Blasien           Vogelbach, St. Blasien
# 24                        Freiburg                         Freiburg
# 25                        Barleben                         Barleben
# 26              Thalheim, Mittelfr.              Thalheim, Mittelfr.

# %% [markdown]
# ### *Abkürzungen*: 1. Ersetzen allgemeiner Wortendungen

# %% [markdown]
# Function no 1. for substituting abbreviations:
#
# Flexibly substitutes abbreviations that are part of a longer word (e.g. Seekr./Gebirgskr. -> kreis)

# %%
testset['subst_partial'] = Preprocessing.substitute_partial_words(testset['replace_chars'], data_root)
testset
# Out:
#                                         location  \
# 0                       Ostrowine, Oels, Schles.
# 1                      Wald b. Neuburg, Schwaben
# 2                   Rüstenhart, Gebweiler (Els.)
# 3                                Obkaß, vermutl.
# 4                      Gr. Grävendorf, Merseburg
# 5                                 Bühl, Ob. Els.
# 6                      Uhlbach,  O.-A. Cannstatt
# 7                                Wettin, Sallkr.
# 8                  Pietenhofen, nicht Putenkofen
# 9                 Friedrichroda, Mansf. Gebgskr.
# 10                   Hamerode, Mansf. Gebirgskr.
# 11                               Gorko, vermutl.
# 12                           Unterimbach, Mtlfr.
# 13                                    Frankfurt^
# 14               Wenig-Lessen, Grünberg i. Schl.
# 15                         S{.}abott, Hohensalza
# 16                              Burgfelden i. E.
# 17                      Scheuder, nicht Schender
# 18                          Liebenthal, Potsdam^
# 19                         N. Breisig, Ahrweiler
# 20                   Oberhausen, nicht Oberhauen
# 21          Diehlhausen [Dietenhausen], Oberlahn
# 22  Euschertsfurth, Bayern [nicht Enschertsfurt]
# 23                        Vogelbach, St. Blasien
# 24                   Freiburg (nicht Rothenfels)
# 25                              Barleben (vmtl.)
# 26                           Thalheim, Mittelfr.
#
#                       replace_corrs                    replace_chars  \
# 0          Ostrowine, Oels, Schles.         Ostrowine, Oels, Schles.
# 1         Wald b. Neuburg, Schwaben        Wald b. Neuburg, Schwaben
# 2            Rüstenhart, Gebweiler            Rüstenhart, Gebweiler
# 3                             Obkaß                            Obkaß
# 4         Gr. Grävendorf, Merseburg        Gr. Grävendorf, Merseburg
# 5                    Bühl, Ob. Els.                   Bühl, Ob. Els.
# 6         Uhlbach,  O.-A. Cannstatt        Uhlbach,  O.-A. Cannstatt
# 7                   Wettin, Sallkr.                  Wettin, Sallkr.
# 8                       Pietenhofen                      Pietenhofen
# 9    Friedrichroda, Mansf. Gebgskr.   Friedrichroda, Mansf. Gebgskr.
# 10      Hamerode, Mansf. Gebirgskr.      Hamerode, Mansf. Gebirgskr.
# 11                            Gorko                            Gorko
# 12              Unterimbach, Mtlfr.              Unterimbach, Mtlfr.
# 13                       Frankfurt^                        Frankfurt
# 14  Wenig-Lessen, Grünberg i. Schl.  Wenig-Lessen, Grünberg i. Schl.
# 15               Sabott, Hohensalza               Sabott, Hohensalza
# 16                 Burgfelden i. E.                 Burgfelden i. E.
# 17                         Scheuder                         Scheuder
# 18             Liebenthal, Potsdam^              Liebenthal, Potsdam
# 19            N. Breisig, Ahrweiler            N. Breisig, Ahrweiler
# 20                       Oberhausen                       Oberhausen
# 21           Diehlhausen , Oberlahn           Diehlhausen , Oberlahn
# 22          Euschertsfurth, Bayern           Euschertsfurth, Bayern
# 23           Vogelbach, St. Blasien           Vogelbach, St. Blasien
# 24                        Freiburg                         Freiburg
# 25                        Barleben                         Barleben
# 26              Thalheim, Mittelfr.              Thalheim, Mittelfr.
#
#                        subst_partial
# 0           ostrowine, oels, schles.
# 1          wald b. neuburg, schwaben
# 2             rüstenhart, gebweiler
# 3                              obkaß
# 4          gr. grävendorf, merseburg
# 5                     bühl, ob. els.
# 6          uhlbach,  o.-a. cannstatt
# 7                  wettin, sallkreis
# 8                        pietenhofen
# 9   friedrichroda, mansf. gebgskreis
# 10     hamerode, mansf. gebirgskreis
# 11                             gorko
# 12               unterimbach, mtlfr.
# 13                         frankfurt
# 14   wenig-lessen, grünberg i. schl.
# 15                sabott, hohensalza
# 16                  burgfelden i. e.
# 17                          scheuder
# 18               liebenthal, potsdam
# 19             n. breisig, ahrweiler
# 20                        oberhausen
# 21            diehlhausen , oberlahn
# 22           euschertsfurth, bayern
# 23            vogelbach, st. blasien
# 24                         freiburg
# 25                         barleben
# 26               thalheim, mittelfr.

# %% [markdown]
# ### *Abkürzungen*: 2. Löschen von nicht benötigten Typeninformationen

# %% [markdown]
# Function no 2. for substituting abbreviations:
#
# Removes unnecessary abbreviations and extra words that relates to types (e.g. Kr., Kreis, Amtshauptmannschaft)

# %%
testset['subst_delete'] = Preprocessing.substitute_delete_words(testset['subst_partial'], data_root)
testset
# Out:
#                                         location  \
# 0                       Ostrowine, Oels, Schles.
# 1                      Wald b. Neuburg, Schwaben
# 2                   Rüstenhart, Gebweiler (Els.)
# 3                                Obkaß, vermutl.
# 4                      Gr. Grävendorf, Merseburg
# 5                                 Bühl, Ob. Els.
# 6                      Uhlbach,  O.-A. Cannstatt
# 7                                Wettin, Sallkr.
# 8                  Pietenhofen, nicht Putenkofen
# 9                 Friedrichroda, Mansf. Gebgskr.
# 10                   Hamerode, Mansf. Gebirgskr.
# 11                               Gorko, vermutl.
# 12                           Unterimbach, Mtlfr.
# 13                                    Frankfurt^
# 14               Wenig-Lessen, Grünberg i. Schl.
# 15                         S{.}abott, Hohensalza
# 16                              Burgfelden i. E.
# 17                      Scheuder, nicht Schender
# 18                          Liebenthal, Potsdam^
# 19                         N. Breisig, Ahrweiler
# 20                   Oberhausen, nicht Oberhauen
# 21          Diehlhausen [Dietenhausen], Oberlahn
# 22  Euschertsfurth, Bayern [nicht Enschertsfurt]
# 23                        Vogelbach, St. Blasien
# 24                   Freiburg (nicht Rothenfels)
# 25                              Barleben (vmtl.)
# 26                           Thalheim, Mittelfr.
#
#                       replace_corrs                    replace_chars  \
# 0          Ostrowine, Oels, Schles.         Ostrowine, Oels, Schles.
# 1         Wald b. Neuburg, Schwaben        Wald b. Neuburg, Schwaben
# 2            Rüstenhart, Gebweiler            Rüstenhart, Gebweiler
# 3                             Obkaß                            Obkaß
# 4         Gr. Grävendorf, Merseburg        Gr. Grävendorf, Merseburg
# 5                    Bühl, Ob. Els.                   Bühl, Ob. Els.
# 6         Uhlbach,  O.-A. Cannstatt        Uhlbach,  O.-A. Cannstatt
# 7                   Wettin, Sallkr.                  Wettin, Sallkr.
# 8                       Pietenhofen                      Pietenhofen
# 9    Friedrichroda, Mansf. Gebgskr.   Friedrichroda, Mansf. Gebgskr.
# 10      Hamerode, Mansf. Gebirgskr.      Hamerode, Mansf. Gebirgskr.
# 11                            Gorko                            Gorko
# 12              Unterimbach, Mtlfr.              Unterimbach, Mtlfr.
# 13                       Frankfurt^                        Frankfurt
# 14  Wenig-Lessen, Grünberg i. Schl.  Wenig-Lessen, Grünberg i. Schl.
# 15               Sabott, Hohensalza               Sabott, Hohensalza
# 16                 Burgfelden i. E.                 Burgfelden i. E.
# 17                         Scheuder                         Scheuder
# 18             Liebenthal, Potsdam^              Liebenthal, Potsdam
# 19            N. Breisig, Ahrweiler            N. Breisig, Ahrweiler
# 20                       Oberhausen                       Oberhausen
# 21           Diehlhausen , Oberlahn           Diehlhausen , Oberlahn
# 22          Euschertsfurth, Bayern           Euschertsfurth, Bayern
# 23           Vogelbach, St. Blasien           Vogelbach, St. Blasien
# 24                        Freiburg                         Freiburg
# 25                        Barleben                         Barleben
# 26              Thalheim, Mittelfr.              Thalheim, Mittelfr.
#
#                        subst_partial                      subst_delete
# 0           ostrowine, oels, schles.          ostrowine, oels, schles.
# 1          wald b. neuburg, schwaben         wald b. neuburg, schwaben
# 2             rüstenhart, gebweiler             rüstenhart, gebweiler
# 3                              obkaß                             obkaß
# 4          gr. grävendorf, merseburg         gr. grävendorf, merseburg
# 5                     bühl, ob. els.                    bühl, ob. els.
# 6          uhlbach,  o.-a. cannstatt              uhlbach,   cannstatt
# 7                  wettin, sallkreis                 wettin, sallkreis
# 8                        pietenhofen                       pietenhofen
# 9   friedrichroda, mansf. gebgskreis  friedrichroda, mansf. gebgskreis
# 10     hamerode, mansf. gebirgskreis     hamerode, mansf. gebirgskreis
# 11                             gorko                             gorko
# 12               unterimbach, mtlfr.               unterimbach, mtlfr.
# 13                         frankfurt                         frankfurt
# 14   wenig-lessen, grünberg i. schl.   wenig-lessen, grünberg i. schl.
# 15                sabott, hohensalza                sabott, hohensalza
# 16                  burgfelden i. e.                  burgfelden i. e.
# 17                          scheuder                          scheuder
# 18               liebenthal, potsdam               liebenthal, potsdam
# 19             n. breisig, ahrweiler             n. breisig, ahrweiler
# 20                        oberhausen                        oberhausen
# 21            diehlhausen , oberlahn            diehlhausen , oberlahn
# 22           euschertsfurth, bayern            euschertsfurth, bayern
# 23            vogelbach, st. blasien            vogelbach, st. blasien
# 24                         freiburg                          freiburg
# 25                         barleben                          barleben
# 26               thalheim, mittelfr.               thalheim, mittelfr.

# %% [markdown]
# ### *Abkürzungen*: 3. Spezifische Ersetzungen

# %% [markdown]
# Function no 3. for substituting abbreviations:
#
# Substitutes specific abbreviations

# %%
testset['subst_full'] = Preprocessing.substitute_full_words(testset['subst_delete'], data_root)
testset
# Out:
#                                         location  \
# 0                       Ostrowine, Oels, Schles.
# 1                      Wald b. Neuburg, Schwaben
# 2                   Rüstenhart, Gebweiler (Els.)
# 3                                Obkaß, vermutl.
# 4                      Gr. Grävendorf, Merseburg
# 5                                 Bühl, Ob. Els.
# 6                      Uhlbach,  O.-A. Cannstatt
# 7                                Wettin, Sallkr.
# 8                  Pietenhofen, nicht Putenkofen
# 9                 Friedrichroda, Mansf. Gebgskr.
# 10                   Hamerode, Mansf. Gebirgskr.
# 11                               Gorko, vermutl.
# 12                           Unterimbach, Mtlfr.
# 13                                    Frankfurt^
# 14               Wenig-Lessen, Grünberg i. Schl.
# 15                         S{.}abott, Hohensalza
# 16                              Burgfelden i. E.
# 17                      Scheuder, nicht Schender
# 18                          Liebenthal, Potsdam^
# 19                         N. Breisig, Ahrweiler
# 20                   Oberhausen, nicht Oberhauen
# 21          Diehlhausen [Dietenhausen], Oberlahn
# 22  Euschertsfurth, Bayern [nicht Enschertsfurt]
# 23                        Vogelbach, St. Blasien
# 24                   Freiburg (nicht Rothenfels)
# 25                              Barleben (vmtl.)
# 26                           Thalheim, Mittelfr.
#
#                       replace_corrs                    replace_chars  \
# 0          Ostrowine, Oels, Schles.         Ostrowine, Oels, Schles.
# 1         Wald b. Neuburg, Schwaben        Wald b. Neuburg, Schwaben
# 2            Rüstenhart, Gebweiler            Rüstenhart, Gebweiler
# 3                             Obkaß                            Obkaß
# 4         Gr. Grävendorf, Merseburg        Gr. Grävendorf, Merseburg
# 5                    Bühl, Ob. Els.                   Bühl, Ob. Els.
# 6         Uhlbach,  O.-A. Cannstatt        Uhlbach,  O.-A. Cannstatt
# 7                   Wettin, Sallkr.                  Wettin, Sallkr.
# 8                       Pietenhofen                      Pietenhofen
# 9    Friedrichroda, Mansf. Gebgskr.   Friedrichroda, Mansf. Gebgskr.
# 10      Hamerode, Mansf. Gebirgskr.      Hamerode, Mansf. Gebirgskr.
# 11                            Gorko                            Gorko
# 12              Unterimbach, Mtlfr.              Unterimbach, Mtlfr.
# 13                       Frankfurt^                        Frankfurt
# 14  Wenig-Lessen, Grünberg i. Schl.  Wenig-Lessen, Grünberg i. Schl.
# 15               Sabott, Hohensalza               Sabott, Hohensalza
# 16                 Burgfelden i. E.                 Burgfelden i. E.
# 17                         Scheuder                         Scheuder
# 18             Liebenthal, Potsdam^              Liebenthal, Potsdam
# 19            N. Breisig, Ahrweiler            N. Breisig, Ahrweiler
# 20                       Oberhausen                       Oberhausen
# 21           Diehlhausen , Oberlahn           Diehlhausen , Oberlahn
# 22          Euschertsfurth, Bayern           Euschertsfurth, Bayern
# 23           Vogelbach, St. Blasien           Vogelbach, St. Blasien
# 24                        Freiburg                         Freiburg
# 25                        Barleben                         Barleben
# 26              Thalheim, Mittelfr.              Thalheim, Mittelfr.
#
#                        subst_partial                      subst_delete  \
# 0           ostrowine, oels, schles.          ostrowine, oels, schles.
# 1          wald b. neuburg, schwaben         wald b. neuburg, schwaben
# 2             rüstenhart, gebweiler             rüstenhart, gebweiler
# 3                              obkaß                             obkaß
# 4          gr. grävendorf, merseburg         gr. grävendorf, merseburg
# 5                     bühl, ob. els.                    bühl, ob. els.
# 6          uhlbach,  o.-a. cannstatt              uhlbach,   cannstatt
# 7                  wettin, sallkreis                 wettin, sallkreis
# 8                        pietenhofen                       pietenhofen
# 9   friedrichroda, mansf. gebgskreis  friedrichroda, mansf. gebgskreis
# 10     hamerode, mansf. gebirgskreis     hamerode, mansf. gebirgskreis
# 11                             gorko                             gorko
# 12               unterimbach, mtlfr.               unterimbach, mtlfr.
# 13                         frankfurt                         frankfurt
# 14   wenig-lessen, grünberg i. schl.   wenig-lessen, grünberg i. schl.
# 15                sabott, hohensalza                sabott, hohensalza
# 16                  burgfelden i. e.                  burgfelden i. e.
# 17                          scheuder                          scheuder
# 18               liebenthal, potsdam               liebenthal, potsdam
# 19             n. breisig, ahrweiler             n. breisig, ahrweiler
# 20                        oberhausen                        oberhausen
# 21            diehlhausen , oberlahn            diehlhausen , oberlahn
# 22           euschertsfurth, bayern            euschertsfurth, bayern
# 23            vogelbach, st. blasien            vogelbach, st. blasien
# 24                         freiburg                          freiburg
# 25                         barleben                          barleben
# 26               thalheim, mittelfr.               thalheim, mittelfr.
#
#                               subst_full
# 0             ostrowine, oels, schlesien
# 1              wald b. neuburg, schwaben
# 2                 rüstenhart, gebweiler
# 3                                  obkaß
# 4             groß grävendorf, merseburg
# 5                       bühl, ober elsaß
# 6                   uhlbach,   cannstatt
# 7                      wettin, sallkreis
# 8                            pietenhofen
# 9   friedrichroda, mansfelder gebgskreis
# 10     hamerode, mansfelder gebirgskreis
# 11                                 gorko
# 12            unterimbach, mittelfranken
# 13                             frankfurt
# 14   wenig-lessen, grünberg i. schlesien
# 15                    sabott, hohensalza
# 16                      burgfelden i. e.
# 17                              scheuder
# 18                   liebenthal, potsdam
# 19                 n. breisig, ahrweiler
# 20                            oberhausen
# 21                diehlhausen , oberlahn
# 22               euschertsfurth, bayern
# 23              vogelbach, sankt blasien
# 24                             freiburg
# 25                             barleben
# 26               thalheim, mittelfranken

# %% [markdown]
# ### Zusätzlich optionale Funktion: " i." (für in) durch Komma ersetzen
#
# (Achtung: n+1 Bestandteile)

# %%
testset['subst_i'] = testset.subst_full.replace(to_replace=" i\.", value=",", regex=True)
testset
# Out:
#                                         location  \
# 0                       Ostrowine, Oels, Schles.
# 1                      Wald b. Neuburg, Schwaben
# 2                   Rüstenhart, Gebweiler (Els.)
# 3                                Obkaß, vermutl.
# 4                      Gr. Grävendorf, Merseburg
# 5                                 Bühl, Ob. Els.
# 6                      Uhlbach,  O.-A. Cannstatt
# 7                                Wettin, Sallkr.
# 8                  Pietenhofen, nicht Putenkofen
# 9                 Friedrichroda, Mansf. Gebgskr.
# 10                   Hamerode, Mansf. Gebirgskr.
# 11                               Gorko, vermutl.
# 12                           Unterimbach, Mtlfr.
# 13                                    Frankfurt^
# 14               Wenig-Lessen, Grünberg i. Schl.
# 15                         S{.}abott, Hohensalza
# 16                              Burgfelden i. E.
# 17                      Scheuder, nicht Schender
# 18                          Liebenthal, Potsdam^
# 19                         N. Breisig, Ahrweiler
# 20                   Oberhausen, nicht Oberhauen
# 21          Diehlhausen [Dietenhausen], Oberlahn
# 22  Euschertsfurth, Bayern [nicht Enschertsfurt]
# 23                        Vogelbach, St. Blasien
# 24                   Freiburg (nicht Rothenfels)
# 25                              Barleben (vmtl.)
# 26                           Thalheim, Mittelfr.
#
#                       replace_corrs                    replace_chars  \
# 0          Ostrowine, Oels, Schles.         Ostrowine, Oels, Schles.
# 1         Wald b. Neuburg, Schwaben        Wald b. Neuburg, Schwaben
# 2            Rüstenhart, Gebweiler            Rüstenhart, Gebweiler
# 3                             Obkaß                            Obkaß
# 4         Gr. Grävendorf, Merseburg        Gr. Grävendorf, Merseburg
# 5                    Bühl, Ob. Els.                   Bühl, Ob. Els.
# 6         Uhlbach,  O.-A. Cannstatt        Uhlbach,  O.-A. Cannstatt
# 7                   Wettin, Sallkr.                  Wettin, Sallkr.
# 8                       Pietenhofen                      Pietenhofen
# 9    Friedrichroda, Mansf. Gebgskr.   Friedrichroda, Mansf. Gebgskr.
# 10      Hamerode, Mansf. Gebirgskr.      Hamerode, Mansf. Gebirgskr.
# 11                            Gorko                            Gorko
# 12              Unterimbach, Mtlfr.              Unterimbach, Mtlfr.
# 13                       Frankfurt^                        Frankfurt
# 14  Wenig-Lessen, Grünberg i. Schl.  Wenig-Lessen, Grünberg i. Schl.
# 15               Sabott, Hohensalza               Sabott, Hohensalza
# 16                 Burgfelden i. E.                 Burgfelden i. E.
# 17                         Scheuder                         Scheuder
# 18             Liebenthal, Potsdam^              Liebenthal, Potsdam
# 19            N. Breisig, Ahrweiler            N. Breisig, Ahrweiler
# 20                       Oberhausen                       Oberhausen
# 21           Diehlhausen , Oberlahn           Diehlhausen , Oberlahn
# 22          Euschertsfurth, Bayern           Euschertsfurth, Bayern
# 23           Vogelbach, St. Blasien           Vogelbach, St. Blasien
# 24                        Freiburg                         Freiburg
# 25                        Barleben                         Barleben
# 26              Thalheim, Mittelfr.              Thalheim, Mittelfr.
#
#                        subst_partial                      subst_delete  \
# 0           ostrowine, oels, schles.          ostrowine, oels, schles.
# 1          wald b. neuburg, schwaben         wald b. neuburg, schwaben
# 2             rüstenhart, gebweiler             rüstenhart, gebweiler
# 3                              obkaß                             obkaß
# 4          gr. grävendorf, merseburg         gr. grävendorf, merseburg
# 5                     bühl, ob. els.                    bühl, ob. els.
# 6          uhlbach,  o.-a. cannstatt              uhlbach,   cannstatt
# 7                  wettin, sallkreis                 wettin, sallkreis
# 8                        pietenhofen                       pietenhofen
# 9   friedrichroda, mansf. gebgskreis  friedrichroda, mansf. gebgskreis
# 10     hamerode, mansf. gebirgskreis     hamerode, mansf. gebirgskreis
# 11                             gorko                             gorko
# 12               unterimbach, mtlfr.               unterimbach, mtlfr.
# 13                         frankfurt                         frankfurt
# 14   wenig-lessen, grünberg i. schl.   wenig-lessen, grünberg i. schl.
# 15                sabott, hohensalza                sabott, hohensalza
# 16                  burgfelden i. e.                  burgfelden i. e.
# 17                          scheuder                          scheuder
# 18               liebenthal, potsdam               liebenthal, potsdam
# 19             n. breisig, ahrweiler             n. breisig, ahrweiler
# 20                        oberhausen                        oberhausen
# 21            diehlhausen , oberlahn            diehlhausen , oberlahn
# 22           euschertsfurth, bayern            euschertsfurth, bayern
# 23            vogelbach, st. blasien            vogelbach, st. blasien
# 24                         freiburg                          freiburg
# 25                         barleben                          barleben
# 26               thalheim, mittelfr.               thalheim, mittelfr.
#
#                               subst_full                               subst_i
# 0             ostrowine, oels, schlesien            ostrowine, oels, schlesien
# 1              wald b. neuburg, schwaben             wald b. neuburg, schwaben
# 2                 rüstenhart, gebweiler                 rüstenhart, gebweiler
# 3                                  obkaß                                 obkaß
# 4             groß grävendorf, merseburg            groß grävendorf, merseburg
# 5                       bühl, ober elsaß                      bühl, ober elsaß
# 6                   uhlbach,   cannstatt                  uhlbach,   cannstatt
# 7                      wettin, sallkreis                     wettin, sallkreis
# 8                            pietenhofen                           pietenhofen
# 9   friedrichroda, mansfelder gebgskreis  friedrichroda, mansfelder gebgskreis
# 10     hamerode, mansfelder gebirgskreis     hamerode, mansfelder gebirgskreis
# 11                                 gorko                                 gorko
# 12            unterimbach, mittelfranken            unterimbach, mittelfranken
# 13                             frankfurt                             frankfurt
# 14   wenig-lessen, grünberg i. schlesien     wenig-lessen, grünberg, schlesien
# 15                    sabott, hohensalza                    sabott, hohensalza
# 16                      burgfelden i. e.                        burgfelden, e.
# 17                              scheuder                              scheuder
# 18                   liebenthal, potsdam                   liebenthal, potsdam
# 19                 n. breisig, ahrweiler                 n. breisig, ahrweiler
# 20                            oberhausen                            oberhausen
# 21                diehlhausen , oberlahn                diehlhausen , oberlahn
# 22               euschertsfurth, bayern                euschertsfurth, bayern
# 23              vogelbach, sankt blasien              vogelbach, sankt blasien
# 24                             freiburg                              freiburg
# 25                             barleben                              barleben
# 26               thalheim, mittelfranken               thalheim, mittelfranken
